# %%
import mykf
reload(mykf)
# Out:
# <module 'mykf' from 'mykf.py'>

# %%
df = mykf.crosstab()
# Out:
# predicted           LAYING  SITTING  STANDING  WALKING  WALKING_DOWNSTAIRS  \
# actual
# LAYING                   0        0         0       51                 373
# SITTING                  1        0         0      140                  68
# STANDING                 0        0         0      293                  37
# WALKING                 99      327        39        0                   0
# WALKING_DOWNSTAIRS      42       39       258        0                   0
# WALKING_UPSTAIRS       179      144        49        0                   0
#
# predicted           WALKING_UPSTAIRS
# actual
# LAYING                            67
# SITTING                          236
# STANDING                         120
# WALKING                            0
# WALKING_DOWNSTAIRS                 0
# WALKING_UPSTAIRS                   0

# %%
df.shape
# Out:
# (10299, 431)

# %%
df.head()
# Out:
#    tAcc-Mean-X1  tAcc-Mean-Y2  tAcc-Mean-Z3  tAcc-STD-X4  tAcc-STD-Y5  \
# 0      0.257178     -0.023285     -0.014654    -0.938404    -0.920091
# 1      0.286027     -0.013163     -0.119083    -0.975415    -0.967458
# 2      0.275485     -0.026050     -0.118152    -0.993819    -0.969926
# 3      0.270298     -0.032614     -0.117520    -0.994743    -0.973268
# 4      0.274833     -0.027848     -0.129527    -0.993852    -0.967445
#
#    tAcc-STD-Z6  tAcc-mad-X7  tAcc-mad-Y8  tAcc-mad-Z9  tAcc-max-X10    ...     \
# 0    -0.667683    -0.952501    -0.925249    -0.674302     -0.894088    ...
# 1    -0.944958    -0.986799    -0.968401    -0.945823     -0.894088    ...
# 2    -0.962748    -0.994403    -0.970735    -0.963483     -0.939260    ...
# 3    -0.967091    -0.995274    -0.974471    -0.968897     -0.938610    ...
# 4    -0.978295    -0.994111    -0.965953    -0.977346     -0.938610    ...
#
#    fGyroJerk-energy548  fGyroJerk-iqr549  fGyroJerk-entropy550  \
# ...

# %%
print(mykf.crosstab())
# Out:
# predicted           LAYING  SITTING  STANDING  WALKING  WALKING_DOWNSTAIRS  \
# actual
# LAYING                   2        0         0       51                 385
# SITTING                  0        0         0      153                  56
# STANDING                 0        0         0      328                  43
# WALKING                 92      300        34        1                   0
# WALKING_DOWNSTAIRS      43       35       285        0                   0
# WALKING_UPSTAIRS       186      161        53        0                   0
#
# predicted           WALKING_UPSTAIRS
# actual
# LAYING                            77
# SITTING                          233
# STANDING                         105
# WALKING                            0
# WALKING_DOWNSTAIRS                 0
# WALKING_UPSTAIRS                   0
#       tAcc-Mean-X1  tAcc-Mean-Y2  tAcc-Mean-Z3  tAcc-STD-X4  tAcc-STD-Y5  \
# 0         0.257178     -0.023285     -0.014654    -0.938404    -0.920091
# ...

# %%
for x in df.columns:
    print(df[x].dtype)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# ...

# %%
for y in agg.columns:
    if(agg[y].dtype == np.float64 or agg[y].dtype == np.int64):
          treat_numeric(agg[y])
    else:
          treat_str(agg[y])
